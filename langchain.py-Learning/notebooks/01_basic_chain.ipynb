# %% [markdown]
# # LangChain 快速入门
#
# 当前 notebook 用来验证 prompt template + structured output 的最小链路：
#
# 1. 读取并校验环境变量
# 2. 连接 Ollama 模型
# 3. 跑通 prompt template 版本的 basic chain
# 4. 跑通 structured output 版本的 chain
# 5. 验证不同输入会得到稳定结构

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

from src.config.env import load_env
from src.models.ollama import create_ollama_chat_model
from src.chains.basic_chain import run_basic_chain, run_structured_chain

# %%
env = load_env()
print({
    "ollama_base_url": env.ollama_base_url,
    "ollama_model": env.ollama_model,
})
# Out:
# {'ollama_base_url': 'http://localhost:11434', 'ollama_model': 'qwen3:8b'}

# %%
model = create_ollama_chat_model()
response = model.invoke("请用一句话介绍 LangChain 的作用。")
print(response.content if isinstance(response.content, str) else str(response.content))
# Out:
# LangChain 是一个用于构建和运行语言模型应用的框架，通过整合模型、数据存储、提示模板等组件，帮助开发者高效地创建能够与外部数据和工具交互的智能应用。

# %%
result = run_basic_chain("请用一句话介绍 LangChain 的作用。")
print(result)

another_result = run_basic_chain("什么是 prompt template？")
print(another_result)

structured_result = run_structured_chain("请用一句话介绍 LangChain 的作用。")
print(structured_result)
print(structured_result.question)
print(structured_result.answer)
print(structured_result.key_points)

another_structured_result = run_structured_chain("什么是 prompt template？")
print(another_structured_result)
print(another_structured_result.question)
print(another_structured_result.answer)
print(another_structured_result.key_points)
# Out:
# LangChain 是一个用于构建和运行语言模型应用的框架，通过连接模型、数据和工具，简化复杂流程并提升开发效率。
# Prompt template（提示模板）是用于生成提示语的结构化格式，通常包含占位符（如{主题}、{数量}等），通过替换占位符生成具体提示。它能统一提示格式，提高效率，并确保输出符合特定需求。例如：
# **模板**：请帮我分析{主题}，并给出{数量}个要点。
# **替换后**：请帮我分析人工智能，给出5个要点。
# question='请用一句话介绍 LangChain 的作用。' answer='LangChain 是一个用于构建语言模型应用的框架，通过连接不同模型和工具简化复杂场景的开发。' key_points=['连接语言模型与外部工具', '降低应用开发复杂度', '支持多模型与多工具协作', '提供可扩展的框架结构']
# 请用一句话介绍 LangChain 的作用。
# LangChain 是一个用于构建语言模型应用的框架，通过连接不同模型和工具简化复杂场景的开发。
# ['连接语言模型与外部工具', '降低应用开发复杂度', '支持多模型与多工具协作', '提供可扩展的框架结构']
# question='什么是 prompt template？' answer='Prompt template 是一种用于生成结构化提示语的模板，通过定义固定格式和占位符，帮助用户更高效地构造指令以引导模型输出。' key_points=['定义：预设的指令格式模板，包含固定文本和变量占位符', '作用：提升提示语的一致性与可复用性，简化复杂指令的构建', '常见元素：指令说明、输入示例、输出格式要求等结构化组件', '使用场景：代码生成、数据标注、多轮对话等需要明确指令的场景']
# 什么是 prompt template？
# Prompt template 是一种用于生成结构化提示语的模板，通过定义固定格式和占位符，帮助用户更高效地构造指令以引导模型输出。
# ['定义：预设的指令格式模板，包含固定文本和变量占位符', '作用：提升提示语的一致性与可复用性，简化复杂指令的构建', '常见元素：指令说明、输入示例、输出格式要求等结构化组件', '使用场景：代码生成、数据标注、多轮对话等需要明确指令的场景']
