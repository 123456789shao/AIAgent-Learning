# %% [markdown]
# # LangChain Skill 快速入门
#
# 当前 notebook 用来验证最小 skill 链路：
#
# 1. 读取并校验环境变量
# 2. 查看已注册的 skill
# 3. 执行 weather-brief skill
# 4. 验证缺少参数时的 skill 级报错
# 5. 验证未知 skill name 时的报错
# 6. 对比直接 tool 输出与 skill 输出

# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

from src.config.env import load_env
from src.chains.skill_chain import run_skill
from src.skills.skill_registry import get_registered_skill_names
from src.tools.weather import get_weather

# %%
env = load_env()
print({
    "ollama_base_url": env.ollama_base_url,
    "ollama_model": env.ollama_model,
    "weather_api_key_configured": bool(env.weather_api_key),
})

# %%
print(get_registered_skill_names())

# %%
skill_result = run_skill("skill-demo", "weather-brief", {"city": "北京"})
print(skill_result)

# %%
print(run_skill("skill-demo", "weather-brief", {}))

# %%
print(run_skill("skill-demo", "unknown-skill", {"city": "北京"}))

# %%
print(get_weather.invoke({"city": "北京"}))
print(run_skill("skill-demo", "weather-brief", {"city": "北京"})["output"])
